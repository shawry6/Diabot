# %%
import pandas as pd
import googlemaps 
from pathlib import Path
# %matplotlib inline

# %%
csv_path = Path("../Project 2/book1.csv")
data = pd.read_csv(csv_path)
data.head()
# Out:
#    id                             name   latitude  longtitude  \
# 0   1                        iFitGroup -33.915626  151.111029
# 1   2                  Diabetes centre -33.918874  151.242150
# 2   3  EllaWell Diabetes Clinic Sydney -33.890896  151.254802
# 3   4               Jenkins Laboratory -33.885181  151.179768
# 4   5                           ADIPS  -33.864152  151.212915
#
#                                coordinates
# 0  -33.915626418996155, 151.11102883390836
# 1     -33.9188737554643, 151.2421497175593
# 2   -33.89089579791249, 151.25480223238344
# 3  -33.885180626274554, 151.17976851964104
# 4  -33.864151868248776, 151.21291515722191

# %%
API_key = 'AIzaSyBo7t0uoPQx6ZlXSHBfnbk6hS1uFfbtR-I'  

gmaps = googlemaps.Client(key=API_key)



origin = (-33.829214356688816, 151.22757299746542)
destinations = data.coordinates


actual_duration = []


for destination in destinations:
    result = gmaps.distance_matrix(origin, destination, mode='driving')["rows"][0]["elements"][0]["duration"]["value"]  
    result = result/3600
    actual_duration.append(result)
    


#Add the list of coordinates to the main data set

data["duration (Hours)"] = actual_duration


data.head(10)
# Out:
#    id                              name   latitude  longtitude  \
# 0   1                         iFitGroup -33.915626  151.111029
# 1   2                   Diabetes centre -33.918874  151.242150
# 2   3   EllaWell Diabetes Clinic Sydney -33.890896  151.254802
# 3   4                Jenkins Laboratory -33.885181  151.179768
# 4   5                            ADIPS  -33.864152  151.212915
# 5   6       Sydney Endocrine Associates -33.875354  151.220036
# 6   7  Sydney Endorinology and Diabetes -33.913307  151.249294
# 7   8       Hormone Health and Diabetes -33.874925  151.107505
# 8   9             Immediate Health Care -33.876546  151.215979
# 9  10            Sally Inglis Diabetes  -33.795502  151.190640
#
#                                coordinates  duration (Hours)
# 0  -33.915626418996155, 151.11102883390836          0.484444
# 1     -33.9188737554643, 151.2421497175593          0.343333
# 2   -33.89089579791249, 151.25480223238344          0.288611
# 3  -33.885180626274554, 151.17976851964104          0.281111
# 4  -33.864151868248776, 151.21291515722191          0.169444
# 5   -33.87535374130988, 151.22003579762855          0.242778
# 6   -33.91330740421907, 151.24929408775427          0.338889
# 7  -33.874925182732234, 151.10750449915386          0.425833
# 8      -33.876545549805, 151.2159789682017          0.212222
# 9  -33.795501871687186, 151.19063972187772          0.234722

# %%
API_key = 'AIzaSyBo7t0uoPQx6ZlXSHBfnbk6hS1uFfbtR-I'
gmaps = googlemaps.Client(key=API_key)



origin = (-33.829214356688816, 151.22757299746542)
geocode_result = gmaps.geocode ('320 Military Road, Cremorne, NSW, 2090')
destinations = data.coordinates


actual_distance = []


for destination in destinations:
    result = gmaps.distance_matrix(origin, destination, mode='driving')["rows"][0]["elements"][0]["distance"]["value"]  
    result = result/1000
    actual_distance.append(result)
    


#Add the list of coordinates to the main data set

data["distance (Km)"] = actual_distance


data.head(15)
# Out:
#     id                              name   latitude  longtitude  \
# 0    1                         iFitGroup -33.915626  151.111029
# 1    2                   Diabetes centre -33.918874  151.242150
# 2    3   EllaWell Diabetes Clinic Sydney -33.890896  151.254802
# 3    4                Jenkins Laboratory -33.885181  151.179768
# 4    5                            ADIPS  -33.864152  151.212915
# 5    6       Sydney Endocrine Associates -33.875354  151.220036
# 6    7  Sydney Endorinology and Diabetes -33.913307  151.249294
# 7    8       Hormone Health and Diabetes -33.874925  151.107505
# 8    9             Immediate Health Care -33.876546  151.215979
# 9   10            Sally Inglis Diabetes  -33.795502  151.190640
# 10  11  Northern Sydney Endocrine Centre -33.821302  151.202894
#
#                                 coordinates  duration (Hours)  distance (Km)
# 0   -33.915626418996155, 151.11102883390836          0.484444         19.001
# 1      -33.9188737554643, 151.2421497175593          0.343333         13.844
# 2    -33.89089579791249, 151.25480223238344          0.288611         12.687
# 3   -33.885180626274554, 151.17976851964104          0.281111         10.308
# 4   -33.864151868248776, 151.21291515722191          0.169444          7.949
# 5    -33.87535374130988, 151.22003579762855          0.242778          8.523
# 6    -33.91330740421907, 151.24929408775427          0.338889         14.006
# 7   -33.874925182732234, 151.10750449915386          0.425833         17.814
# 8       -33.876545549805, 151.2159789682017          0.212222          8.094
# 9   -33.795501871687186, 151.19063972187772          0.234722          7.249
# 10   -33.82130231424912, 151.20289392902836          0.159722          4.561
